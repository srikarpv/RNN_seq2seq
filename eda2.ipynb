# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("/home/srikar/Downloads/work/Financial1.csv")
df2 = pd.read_csv("/home/srikar/Downloads/work/Financial2.csv")

# %%
df1.columns = ['asu', 'block_address','size', 'opcode','time_stamp']
df2.columns = ['asu', 'block_address','size', 'opcode','time_stamp']

# %%
df1.head(3)
# Out:
#    asu  block_address  size opcode  time_stamp
# 0    1          55590  3072      w    0.000000
# 1    0         303574  3584      w    0.026214
# 2    1         240840  3072      w    0.026214

# %%
pp = df1.head(20000)
sns.pairplot(pp)

# %%
#check the shape of df
print(df1.shape)
#check for null values
df1.isnull().sum()
# Out:
# (5334986, 5)
# asu              0
# block_address    0
# size             0
# opcode           0
# time_stamp       0
# dtype: int64

# %%
df1.dtypes
# Out:
# asu                int64
# block_address      int64
# size               int64
# opcode            object
# time_stamp       float64
# dtype: object

# %%
print(df1.block_address.value_counts()[:100])
# Out:
# 753921    90736
# 240840    48742
# 836706    31788
# 837306    31705
# 700132    31289
# 699109    29047
# 373585    25541
# 146550    23887
# 32082     23884
# 146150    23868
# 31682     23868
# 31882     23857
# 146350    23856
# 837815    21252
# 836815    21248
# 838815    18442
# 838315    18424
# 840315    18218
# 841315    18214
# 840815    18208
# 813988    14923
# 799540    14923
# 361644    12432
# 973347    12429
# 760114    12239
# 814488     9425
# 800040     9423
# 361650     8222
# 973353     8218
# 760113     8114
#           ...
# 725002     1435
# 871568     1416
# 871844     1416
# 871842     1416
# 871850     1416
# 289685     1379
# 20684      1378
# 849315     1330
# 1101       1269
# 849815     1256
# 392881     1237
# 392884     1237
# 618509     1215
# 618510     1211
# 624273     1204
# 647427     1165
# 624668     1160
# 647584     1152
# 647579     1152
# 647444     1151
# 618223     1151
# 624861     1094
# 624557     1085
# 770727     1032
# ...

# %%
#check how many unique items there are in a data
for item in df1:
    print (item)
    print (df1[item].nunique())
# Out:
# asu
# 24
# block_address
# 710908
# size
# 142
# opcode
# 2
# time_stamp
# 2452167

# %%
pp.block_address.value_counts().plot(kind='bar', figsize=(40,10), fontsize=15)

# %%
df3 = df1.head(250000)

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df3, alpha=0.6, figsize=(6, 6), diagonal='kde')
# Out:
# /home/srikar/miniconda3/envs/tf_gpu/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a1f7e9ef0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6a0a857940>]], dtype=object)
